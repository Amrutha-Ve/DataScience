# %%
b=["bananana", "apple","ms"]
temp = b[0]
b[0] = b[2]
b[2] = temp

# %%
b
# Out:
# ['ms', 'apple', 'bananana']

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x=list(range(0,10))
y=list(range(-10,0))

plt.plot(x,y)

# %%
a= [0,-100,25,67,-323]
b=[0,3,7,3,9]
plt.axis([-50,80,2,8])
plt.plot(a,b)
